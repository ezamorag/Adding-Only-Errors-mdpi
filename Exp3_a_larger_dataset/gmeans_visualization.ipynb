# %%
import numpy as np
import matplotlib.pyplot as plt

gmeans100 = [[0.96958833, 0.99659695, 0.99623106, 0.99963649, 0.98373688, 0.97452931,
           0.99510014, 0.99793001, 0.97855293, 0.89441548, 0.99928289, 0.9837358,
           0.99960064, 0.9995966,  0.95389047, 0.99945454, 0.76621128, 0.99258334,
           0.9696399,  0.70710678, 0.42470143, 0.76398546, 0.8606517,  0.95013749,
           0.99856041, 0.92751579, 0.8511913,  0.99593218, 0.9987675,  0.87693688,
           0.86456637, 0.68032047, 0.77459392],
          [0.97318081, 0.99563413, 0.99581087, 0.9996398,  0.95882967, 0.96992317,
           0.99999973, 0.99846609, 0.98010406, 0.89042405, 0.99833904, 0.98646489,
           0.99966392, 0.99939607, 0.98171321, 0.99883828, 0.78641741, 0.99637756,
           0.98757501, 0.70710678, 0.26306546, 0.78102407, 0.88609902, 0.98132177,
           0.99875079, 0.93466566, 0.87562292, 0.99478962, 0.99875153, 0.88037391,
           0.8486793,  0.58063006, 0.63245484],
          [0.97284274, 0.99326268, 0.99581114, 0.9982492,  0.65377228, 0.95216776,
           0.99116303, 0.99361154, 0.92768628, 0.83665706, 0.99662795, 0.95320235,
           0.99908721, 0.99854063, 0.98556525, 0.99692682, 0.70026755, 0.99042273,
           0.96473211, 0.    ,     0.22290931, 0.69340925, 0.81648478, 0.96889643,
           0.99734557, 0.86569869, 0.7844318,  0.99088649, 0.99827573, 0.85620375,
           0.76751693, 0.57070466, 0. ,       ]]
gmeans100 = np.array(gmeans100)

gmeans10 = [[0.96927649, 0.99635277, 0.99748705, 0.9997645, 0.96720204, 0.97728952,
            0.99999973, 0.99831239, 0.98318752, 0.89839954, 0.99920553, 0.97825427,
            0.99949911, 0.99949488, 0.95407488, 0.99938046, 0.76886363, 0.99208623,
            0.97597988, 0.70710678, 0.42665174, 0.75611702, 0.82550856, 0.94879188,
            0.99816967, 0.94174729, 0.83500331, 0.99562468, 0.99871079, 0.88432695,
            0.81596446, 0.70910545, 0.70710562],
            [0.97324409, 0.99565409, 0.99623025, 0.99966579, 0.95461449, 0.96992317,
            0.99999973, 0.99851367, 0.9785572,  0.88640381, 0.99850343, 0.98646515,
            0.99966392, 0.99940419, 0.98259459, 0.99916686, 0.78728196, 0.99637729,
            0.98757527, 0.70710678, 0.2626662,  0.77949072, 0.87769955, 0.98110533,
            0.99877087, 0.93347853, 0.87562364, 0.99473672, 0.99880356, 0.87869316,
            0.84429402, 0.59520882, 0.63245484],
            [0.97253303, 0.99344462, 0.99076639, 0.99781192, 0.73506518, 0.92539866,
            0.98075293, 0.99264803, 0.91783371, 0.79731475, 0.99592064, 0.96022521,
            0.99893772, 0.99824701, 0.97736105, 0.99792042, 0.65919589, 0.98826531,
            0.97791706, 0.        , 0.23192779, 0.74334571, 0.83885722, 0.96625749,
            0.99719847, 0.83173867, 0.74050275, 0.98839682, 0.99788953, 0.84472457,
            0.81292703, 0.42088055, 0.        ,]]
gmeans10 = np.array(gmeans10)



plt.figure(figsize=(10, 6))
plt.subplot(2,1,1)
plt.plot(gmeans100[0,:], 'o-', label='AOE')
plt.plot(gmeans100[1,:], 's--', label='FULL')
plt.plot(gmeans100[2,:], 'x-.', label='RSS')
plt.xticks(ticks=np.arange(33), labels=['' for i in range(33)], rotation=90)
#plt.xlabel('Class')
plt.ylabel('Geometric Mean Score')
plt.ylim(0, 1.05)
plt.title(r'For $b_{\mathrm{AOE}} = 100{,}000$')
plt.legend()
plt.grid(True)

plt.subplot(2,1,2)
plt.plot(gmeans10[0,:], 'o-', label='AOE')
plt.plot(gmeans10[1,:], 's--', label='FULL')
plt.plot(gmeans10[2,:], 'x-.', label='RSS')
plt.xticks(ticks=np.arange(33), labels=[str(i) for i in range(33)], rotation=90)
plt.xlabel('Class')
plt.ylabel('Geometric Mean Score')
plt.ylim(0, 1.05)
plt.title(r'For $b_{\mathrm{AOE}} = 10{,}000$')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.savefig("../figures/cic_collection_gmeans.svg", dpi=300, bbox_inches='tight')  
plt.show()
